# %%
import google.generativeai as genai

# Configure API key
genai.configure(api_key="AIzaSyDJaylop8DhlBJsqHU7NdVOFNmOu7p23Dw")  # Replace with your actual Gemini API key

# Initialize conversation
system_msg = input("What type of chatbot would you like to create?\n")

print("Your new assistant is ready!")

# Load the model
model = genai.GenerativeModel(model_name="gemini-2.5-flash")

# Start chatbot loop
while True:
    user_input = input()
    if user_input.lower() == "quit":
        break

    # Send user input directly (Gemini does not use "role")
    response = model.generate_content(user_input)

    # Extract response
    reply = response.text

    print("\n" + reply + "\n")
# Out:
# What type of chatbot would you like to create?
#  About spare parts
# Your new assistant is ready!
#  provide details on the availabe spare parts
# To provide you with specific details on available spare parts, I need more context. "Spare parts" is a very broad term that applies to virtually every manufactured product, from a simple bicycle to a complex industrial machine.
#
# **Please tell me:**
#
# 1.  **What product or system are you interested in?** (e.g., a specific car model, a brand of appliance, a type of industrial equipment, an electronic device, a bicycle, a piece of furniture, etc.)
# 2.  **What is the manufacturer and model number (and ideally, serial number)?** This is crucial for precise identification.
# 3.  **What type of part are you looking for, or what problem are you trying to solve?** (e.g., "engine components," "replacement screen," "filters for maintenance," "body panel," "circuit board," "gears for a gearbox," "brake pads," "new battery," etc.)
#
# ---
#
# **However, I can provide a general overview of common categories of spare parts and the information usually associated with them:**
#
# ### General Categories of Spare Parts:
#
# 1.  **Consumables/Wear Parts:**
#     *   **Description:** Items designed to be replaced regularly due to wear and tear or limited lifespan.
#     *   **Examples:** Filters (air, oil, fuel, water), gaskets, O-rings, seals, lubricants, light bulbs, brake pads, wiper blades, cutting tools, printing ink/toner cartridges, batteries (some types).
#     *   **Details Provided:** Part number, description, quantity per unit, replacement interval, compatibility, sometimes installation instructions.
#
# 2.  **Mechanical Components:**
#     *   **Description:** Parts that facilitate motion, structural integrity, or power transmission.
#     *   **Examples:** Bearings, gears, shafts, springs, fasteners (nuts, bolts, washers), pulleys, belts, chains, linkages, clutches, pumps, valves.
#     *   **Details Provided:** Part number, dimensions, material, load capacity, compatibility with assemblies, exploded diagrams.
#
# 3.  **Electrical/Electronic Components:**
#     *   **Description:** Parts that handle power, control, sensing, or data processing.
#     *   **Examples:** Wires, cables, connectors, switches, relays, fuses, circuit boards (PCBs), sensors, motors, solenoids, power supplies, resistors, capacitors, displays.
#     *   **Details Provided:** Part number, voltage/current ratings, resistance, capacitance, pin configuration, schematic diagrams, software/firmware compatibility.
#
# 4.  **Structural/Body Parts:**
#     *   **Description:** External or internal components that form the structure, housing, or aesthetics of a product.
#     *   **Examples:** Panels, covers, housings, casings, chassis components, doors, windows, wheels, handles, trim pieces.
#     *   **Details Provided:** Part number, material, color codes, dimensions, mounting points, compatibility with other body parts.
#
# 5.  **Hydraulic/Pneumatic Components:**
#     *   **Description:** Parts for systems that use fluid (oil or air) to transmit power.
#     *   **Examples:** Hoses, fittings, cylinders, pumps, accumulators, control valves.
#     *   **Details Provided:** Part number, pressure ratings, flow rates, connection types, material, seal types.
#
# 6.  **Software/Firmware Licenses & Updates:**
#     *   **Description:** While not physical "parts," these are essential for modern smart products and systems to function correctly or receive new features.
#     *   **Examples:** Operating system updates, application software licenses, firmware upgrades for controllers or sensors.
#     *   **Details Provided:** Version numbers, compatibility matrix, installation procedures, release notes.
#
# ### What Information is Typically Provided for Spare Parts:
#
# When you request details on a specific spare part, you can usually expect to receive:
#
# *   **Part Number (PN):** The unique identifier for the specific part.
# *   **Description:** A clear name for the part (e.g., "Oil Filter," "Front Left Headlight Assembly," "Main Control Board").
# *   **Compatibility:** Which models, years, or versions of the product the part fits.
# *   **Material:** What the part is made of (e.g., "stainless steel," "ABS plastic," "rubber").
# *   **Dimensions/Specifications:** Key measurements or technical ratings (e.g., "12V, 5A," "10mm bore," "M8 thread").
# *   **Quantity per unit:** How many of that part are used in the product.
# *   **Exploded View Diagrams:** Visual representations showing how parts fit together.
# *   **Installation Instructions:** Sometimes included, or a reference to a service manual.
# *   **Availability:** Whether the part is in stock, lead time for ordering.
# *   **Price:** Cost of the part.
# *   **Warranty Information:** Details on the warranty for the spare part itself.
# *   **OEM vs. Aftermarket Options:** Information on whether genuine (Original Equipment Manufacturer) or third-party (aftermarket) parts are available and their differences.
#
# ---
#
# **To get precise details, please provide the information requested at the beginning of this response!**
#  quit
